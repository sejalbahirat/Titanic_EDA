# %% [markdown]
# <a href="https://colab.research.google.com/github/sejalbahirat/Titanic_EDA/blob/main/Titanic_Dataset_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Dataset: It contains information about passengers on the Titanic, including whether they survived or not, their age, gender, class, fare, and more.

# %%
# Ignore Warnings
import warnings
warnings.filterwarnings('ignore')

# Importing required libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('/content/drive/MyDrive/CSV Files/titanic.csv')
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# To display max rows and columns
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
# Dimension of the data
print(f'The data has {data.shape[0]} rows and {data.shape[1]} columns.')
print()

# To check the data type of the columns
data.info()
# Out:
# The data has 891 rows and 12 columns.
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
data.describe()

# Columns with the object data types won't be included here. As statiscal analysis can be done for numeric data types only.
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# # Dataset Information
#
# Columns
# *   PassengerId: Unique ID for each passenger
# *   Survived: Survival (0 = No, 1 = Yes)
# *   Pclass: Passenger class (1 = 1st, 2 = 2nd, 3 = 3rd)
# *   Name: Name of the passenger
# *   Sex: Gender of the passenger
# *   Age: Age of the passenger
# *   SibSp: Number of siblings/spouses aboard the Titanic
# *   Parch: Number of parents/children aboard the Titanic
# *   Ticket: Ticket number
# *   Fare: Passenger fare
# *   Cabin: Cabin number
# *   Embarked: Port of embarkation (C = Cherbourg, Q = Queenstown, S = Southampton)

# %%
# Counting the number of numerical and categorical columns using a for loop
num_count, cat_count = 0, 0

for column in data.columns:
    if data.dtypes[column] == 'O':
        cat_count += 1
    else:
        num_count += 1

print(f"Number of Numerical columns: {num_count}")
print(f"Number of Categorical columns: {cat_count}")
# Out:
# Number of Numerical columns: 7
# Number of Categorical columns: 5

# %%
# Categorical columns
cat_col = [col for col in data.columns if data[col].dtype == 'object']
print('Categorical columns :',cat_col)
# Numerical columns
num_col = [col for col in data.columns if data[col].dtype != 'object']
print('Numerical columns :',num_col)
# Out:
# Categorical columns : ['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked']
# Numerical columns : ['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare']

# %%
data[cat_col].nunique()
# Out:
# Name        891
# Sex           2
# Ticket      681
# Cabin       147
# Embarked      3
# dtype: int64

# %%
data[num_col].nunique()
# Out:
# PassengerId    891
# Survived         2
# Pclass           3
# Age             88
# SibSp            7
# Parch            7
# Fare           248
# dtype: int64

# %%
count = data[data.duplicated()].shape
print(f"There are no duplicates in the dataset" if count[0]==0 else f"There are {count[0]} duplicates in the dataset")
# Out:
# There are no duplicates in the dataset

# %% [markdown]
# # Missing Data Visualization

# %%
# Create a heatmap to visualize missing data
sns.heatmap(data.isnull(), yticklabels=False, cbar=False, cmap='viridis')
plt.title('Heatmap of Missing Data')
plt.show()

# %% [markdown]
# Approximately 20% of the Age data is missing. This proportion is likely small enough to allow for reasonable imputation. On the other hand, the Cabin column has too much missing data to be useful at a basic level. We will likely drop this column later or transform it into a different feature, such as "Cabin Known: 1 or 0."

# %% [markdown]
# # Key Observations for EDA
#
# 1. **Survival Distribution**:
#    - The `Survived` column has only 2 unique values, indicating a binary outcome (0 = Did not survive, 1 = Survived). Analyzing this column will help understand the survival rate among passengers.
#
# 2. **Categorical Variables**:
#    - Columns such as `Pclass`, `Sex`, and `Embarked` have a limited number of unique values (3, 2, and 4, respectively). These categorical variables are crucial for understanding how different groups fared in terms of survival.
#
# 3. **High Cardinality Features**:
#    - Columns like `Name` and `Ticket` have high cardinality with 891 and 681 unique values, respectively. They could be explored for more advanced feature engineering or unique passenger insights.
#
# 4. **Missing Data and Imputation**:
#    - The `Age` (89 unique values) and Cabin (148 unique values) likely have missing data that needs imputation for accurate analysis.

# %% [markdown]
# # Removal of Unwanted Observations
# As machines cannot inherently interpret text data, we must handle categorical columns by converting them to numerical types or removing them altogether. In this case, we opt to drop the "Name" column since names are unique and generally do not significantly impact the target variables. The same rationale applies to the "Ticket" column.

# %%
# Removal of unwanted columns
data.drop(columns=['PassengerId', 'Name', 'Ticket','Cabin'], inplace=True)
data.shape
# Out:
# (891, 9)

# %%
# Rename columns
data.rename(columns = {'Pclass':'PassengerClass',
                       'SibSp':'Sibling/Spouse',
                       'Parch':'Parents/Children'},inplace=True)

# %%
# Handling missing data

# Checking the % missing values columns-wise for each row using df.isnull()

round((data.isnull().sum()/data.shape[0])*100,2)
# Out:
# Survived             0.00
# PassengerClass       0.00
# Sex                  0.00
# Age                 19.87
# Sibling/Spouse       0.00
# Parents/Children     0.00
# Fare                 0.00
# Cabin               77.10
# Embarked             0.22
# dtype: float64

# %% [markdown]
# As we can see from the above result that Cabin has 77% null values and Age has 19.87% and Embarked **has** 0.22% of null values. So, it’s not a good idea to fill 77% of null values. So, we will drop the Cabin column. Embarked column has only 0.22% of null values so, we drop the null values rows of Embarked column.

# %%
# Calculate Q1 (25th percentile) and Q3 (75th percentile)
Q1 = data['Age'].quantile(0.25)
Q3 = data['Age'].quantile(0.75)

# Calculate IQR
IQR = Q3 - Q1

# Define the lower and upper bounds
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Find outliers
outliers = data[(data['Age'] < lower_bound) | (data['Age'] > upper_bound)]

# Replace outliers with the median
median_age = data['Age'].median()
data.loc[(data['Age'] < lower_bound) | (data['Age'] > upper_bound), 'Age'] = median_age

# Verify the outliers have been replaced
print(data['Age'].describe())
# Out:
# count    714.000000
# mean      29.055560
# std       13.622807
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       37.000000
# max       64.000000
# Name: Age, dtype: float64

# %%
# Handling null values in 'Embarked'
data['Embarked'].fillna(data['Embarked'].mode()[0], inplace=True)
print(f"Count of Null Values in 'Embarked': {data['Embarked'].isnull().sum()}")

# Correcting erroneous values in 'Embarked'
print(f"Unique values of 'Embarked': {data['Embarked'].unique()}")
data['Embarked'] = data['Embarked'].replace(28.0, data['Embarked'].mode()[0])
print(f"Unique values of 'Embarked' after correction: {data['Embarked'].unique()}")
# Out:
# Count of Null Values in 'Embarked': 0
# Unique values of 'Embarked': ['S' 'C' 'Q']
# Unique values of 'Embarked' after correction: ['S' 'C' 'Q']

# %%
# Handling missing value for numerical column
data.fillna(data['Age'].median(),inplace=True)
print(f"Count of Null Value in 'Age' : {data['Age'].isnull().sum()}")
# Out:
# Count of Null Value in 'Age' : 0

# %%
data.isnull()
# Out:
#      Survived  PassengerClass    Sex    Age  Sibling/Spouse  Parents/Children  \
# 0       False           False  False  False           False             False
# 1       False           False  False  False           False             False
# 2       False           False  False  False           False             False
# 3       False           False  False  False           False             False
# 4       False           False  False  False           False             False
# 5       False           False  False  False           False             False
# 6       False           False  False  False           False             False
# 7       False           False  False  False           False             False
# 8       False           False  False  False           False             False
# 9       False           False  False  False           False             False
# 10      False           False  False  False           False             False
# ...

# %% [markdown]
# # Data Visualizations

# %%
# Create a heatmap to visualize missing data
sns.heatmap(data.isnull(), yticklabels=False, cbar=False, cmap='viridis')
plt.title('Heatmap of Missing Data')
plt.show()

# %%
print(data.columns)
# Out:
# Index(['Survived', 'PassengerClass', 'Sex', 'Age', 'Sibling/Spouse',
#        'Parents/Children', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
sns.countplot(x='PassengerClass', data=data)
plt.title('Passenger Class Distribution')
plt.show()

# %%
sns.countplot(x='Sex', data=data)
plt.title('Gender Distribution')
plt.show()

# %%
# Age distribution
sns.distplot(data['Age'], color='dodgerblue', hist=True, kde_kws={'fill':'True', 'color':'g'})
plt.xlabel('Age')
plt.ylabel('Density')
plt.title('Age Distribution')

# Add grid lines
plt.grid(color='#000000', linestyle=':', axis='y', zorder=0,  dashes=(1,5))

# Remove spines
sns.despine()

plt.show()

# %%
# Fare distribution
sns.distplot(data['Fare'], color='dodgerblue', hist=True, kde_kws={'fill':'True', 'color':'g'})
plt.xlabel('Fare')
plt.ylabel('Density')
plt.title('Fare Distribution')

# Add grid lines
plt.grid(color='#000000', linestyle=':', axis='y', zorder=0,  dashes=(1,5))

# Remove spines
sns.despine()

plt.show()

# %%
# Survival rate by gender
sns.countplot(x='Survived', hue='Sex', data=data)
plt.title('Survival Rate by Gender')
plt.show()

# %%
sns.countplot(x='Survived', hue='PassengerClass', data=data)
plt.title('Survival Rate by Passenger Class')
plt.show()

# %%
sns.boxplot(x='Survived', y='Age', data=data)
plt.title('Survival Rate by Age')
plt.show()

# %%
sns.violinplot(x='Survived', y='Fare', data=data)
plt.title('Survival Rate by Fare')
plt.show()

# %%
sns.pairplot(data[['Survived', 'PassengerClass', 'Sex', 'Age', 'Sibling/Spouse', 'Parents/Children', 'Fare']])
plt.title('Pairplot of Features')
plt.show()

# %%
# Set style and context for better aesthetics (optional)
sns.set(style="ticks", context="talk")

# Create pairplot with enhanced features
pairplot = sns.pairplot(data[['Survived', 'PassengerClass', 'Sex', 'Age', 'Sibling/Spouse', 'Parents/Children', 'Fare']],
                        hue='Survived', # Color by 'Survived' variable
                        diag_kind='hist', # Use histograms for diagonal plots
                        markers=['o', 's'], # Define markers for hue levels (survived or not)
                        plot_kws={'alpha': 0.5}) # Set transparency to improve readability

# Title and labels
pairplot.fig.suptitle('Pairplot of Titanic Dataset Features', y=1.02)
plt.tight_layout()

# Statistical summary (optional)
summary = data[['Survived', 'PassengerClass', 'Sex', 'Age', 'Sibling/Spouse', 'Parents/Children', 'Fare']].describe()
print(summary)

# Show plot
plt.show()
# Out:
#          Survived  PassengerClass         Age  Sibling/Spouse  \
# count  891.000000      891.000000  891.000000      891.000000
# mean     0.383838        2.308642   28.845870        0.523008
# std      0.486592        0.836071   12.200442        1.102743
# min      0.000000        1.000000    0.420000        0.000000
# 25%      0.000000        2.000000   22.000000        0.000000
# 50%      0.000000        3.000000   28.000000        0.000000
# 75%      1.000000        3.000000   35.000000        1.000000
# max      1.000000        3.000000   64.000000        8.000000
#
#        Parents/Children        Fare
# count        891.000000  891.000000
# mean           0.381594   32.204208
# std            0.806057   49.693429
# min            0.000000    0.000000
# 25%            0.000000    7.910400
# 50%            0.000000   14.454200
# 75%            0.000000   31.000000
# max            6.000000  512.329200

# %%
data.head()
# Out:
#    Survived  PassengerClass     Sex   Age  Sibling/Spouse  Parents/Children  \
# 0         0               3    male  22.0               1                 0
# 1         1               1  female  38.0               1                 0
# 2         1               3  female  26.0               0                 0
# 3         1               1  female  35.0               1                 0
# 4         0               3    male  35.0               0                 0
#
#       Fare Cabin Embarked
# 0   7.2500  28.0        S
# 1  71.2833   C85        C
# 2   7.9250  28.0        S
# 3  53.1000  C123        S
# 4   8.0500  28.0        S

# %%
# Convert 'Sex' column to numerical values
data['Sex'] = data['Sex'].map({'male': 0, 'female': 1})

# Verify the conversion
print(data['Sex'].head())
# Out:
# 0    0
# 1    1
# 2    1
# 3    1
# 4    0
# Name: Sex, dtype: int64

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(data.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-48-1c3adbea2e1c> in <cell line: 2>()
#       1 plt.figure(figsize=(10, 8))
# ----> 2 sns.heatmap(data.corr(), annot=True, cmap='coolwarm')
#       3 plt.title('Correlation Matrix')
#       4 plt.show()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in corr(self, method, min_periods, numeric_only)
#   10052         cols = data.columns
#   10053         idx = cols.copy()
# > 10054         mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10055
#   10056         if method == "pearson":
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in to_numpy(self, dtype, copy, na_value)
#    1836         if dtype is not None:
#    1837             dtype = np.dtype(dtype)
# -> 1838         result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
# ...
